# %% [markdown]
# # DATA PREPROCESSING

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Employee Attrition/train.csv')
df_test = pd.read_csv('/content/drive/MyDrive/Employee Attrition/test.csv')

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (1230, 44)
# (240, 42)

# %%
df_train.head()
# Out:
#    ID   Age BusinessTravel  ...  ProjectsContributed Attrition  YearsAtCompany
# 0   1  44.0  Travel_Rarely  ...                 15.0         1              20
# 1   2  25.0     Non-Travel  ...                  7.0         0               6
# 2   3  57.0  Travel_Rarely  ...                  3.0         0               1
# 3   4  47.0  Travel_Rarely  ...                 14.0         0              17
# 4   5  22.0  Travel_Rarely  ...                  5.0         1               1
#
# [5 rows x 44 columns]

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df_train.corr())

# %%
sns.barplot(data=df_train,x=df_train['Attrition'],y=df_train['ContributionIndex'])

# %%
sns.barplot(data=df_train,x=df_train['Attrition'],y=df_train['WorkLifeBalance'])

# %%
sns.barplot(data=df_train,x=df_train['Attrition'],y=df_train['ProjectsContributed'])

# %%
sns.countplot(df_train['Attrition'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_train['EmployeeCount'].value_counts()
# Out:
# 1    1230
# Name: EmployeeCount, dtype: int64

# %%
(1230-197)/1230
# Out:
# 0.8398373983739837

# %%
df_train.corr()
# Out:
#                                 ID       Age  ...  Attrition  YearsAtCompany
# ID                        1.000000  0.015720  ...   0.044866        0.040994
# Age                       0.015720  1.000000  ...  -0.160550        0.310166
# DailyRate                -0.030214  0.002536  ...  -0.051192       -0.031991
# DistanceFromHome          0.014605  0.008483  ...   0.075607        0.010036
# HourlyRate               -0.033243  0.024430  ...  -0.014965       -0.016040
# JobInvolvement           -0.024873  0.029071  ...  -0.097837       -0.012653
# JobLevel                 -0.004617  0.517029  ...  -0.170628        0.521521
# JobSatisfaction          -0.038273 -0.000833  ...  -0.120537       -0.019675
# MonthlyIncome            -0.001927  0.504238  ...  -0.162073        0.503314
# MonthlyRate              -0.031167  0.036105  ...  -0.002527       -0.016200
# NumCompaniesWorked        0.002768  0.290483  ...   0.042284       -0.119532
# ...

# %%
df_train.describe().columns
# Out:
# Index(['ID', 'Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'CommunicationSkill', 'Behaviour', 'Experience',
#        'LvlGrownInOrg', 'ContributionIndex', 'TechnicalExpertise',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'Education',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction',
#        'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'FormalWarnings', 'ProjectsContributed',
#        'Attrition', 'YearsAtCompany'],
#       dtype='object')

# %%
xtrain = df_train.drop(['ID','EmployeeCount','Over18','Behaviour','FormalWarnings','StandardHours','TechnicalExpertise','Attrition','YearsAtCompany'],axis=1)
xtest = df_test.drop(['ID','EmployeeCount','Over18','Behaviour','FormalWarnings','StandardHours','TechnicalExpertise'],axis=1)
df = df_train.drop(['ID'],axis=1)

# %%
df.describe().columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'CommunicationSkill', 'Behaviour', 'Experience', 'LvlGrownInOrg',
#        'ContributionIndex', 'TechnicalExpertise', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'Education', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'WorkLifeBalance', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'FormalWarnings',
#        'ProjectsContributed', 'Attrition', 'YearsAtCompany'],
#       dtype='object')

# %%
# Attrition
outliers = ['ProjectsContributed','TotalWorkingYears','YearsInCurrentRole','YearsWithCurrManager','YearsSinceLastPromotion']

# %%
sns.boxplot(df['YearsWithCurrManager'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df_train['YearsSinceLastPromotion'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# num of yearrs
num_data_null = ['ProjectsContributed','WorkLifeBalance','EnvironmentSatisfaction','YearsSinceLastPromotion',
                 'Education','TotalWorkingYears','RelationshipSatisfaction','LvlGrownInOrg','PercentSalaryHike',
                 'NumCompaniesWorked','MonthlyRate','JobSatisfaction','JobInvolvement','HourlyRate',
                 'DailyRate','Age','EmployeeNumber','StockOptionLevel','Experience','PerformanceRating']

# %%
for i in num_data_null:
  xtrain[[i]]=xtrain[[i]].fillna(xtrain[[i]].mean())
  xtest[[i]]=xtest[[i]].fillna(xtest[[i]].mean())

# %% [markdown]
# # SPLITTING

# %%
Y=df_train.iloc[:,[43]].values

# %%
from sklearn.preprocessing import LabelEncoder

for column in xtrain.columns:
  if xtrain[column].dtype == np.number:
    continue
  xtrain[column] = LabelEncoder().fit_transform(xtrain[column])

for column in xtest.columns:
  if xtest[column].dtype == np.number:
    continue
  xtest[column] = LabelEncoder().fit_transform(xtest[column])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if __name__ == '__main__':

# %%
xtest.head()
# Out:
#    Age  BusinessTravel  ...  YearsWithCurrManager  ProjectsContributed
# 0    8               2  ...                     2                 14.0
# 1    7               2  ...                     0                 30.0
# 2   30               2  ...                     2                  3.0
# 3   22               2  ...                     5                 11.0
# 4    9               2  ...                     2                 10.0
#
# [5 rows x 35 columns]

# %%
'''from sklearn.preprocessing import StandardScaler
norm = StandardScaler()
xtrain = norm.fit_transform(xtrain)
xtest = norm.fit_transform(xtest)'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nnorm = StandardScaler()\nxtrain = norm.fit_transform(xtrain)\nxtest = norm.fit_transform(xtest)'

# %%
smot=xtrain.copy()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(np.asarray(xtrain),np.asarray(Y),test_size=0.25,random_state=6)

# %% [markdown]
# # Years prediction

# %%
import xgboost as xgb
model=xgb.XGBRegressor(max_depth=4,learning_rate=0.1)
#model.fit(X_train, Y_train)
#model.score(X_test,Y_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbmodel= GradientBoostingRegressor(learning_rate=0.1)
#gbmodel.fit(X_train, Y_train)
#gbmodel.score(X_test, Y_test)

# %%
model.fit(xtrain, Y)
# Out:
# [05:57:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=4, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
a = model.predict(xtest)
print(a.shape)
print(a)
# Out:
# (240,)
# [ 2.2491798   2.4265518   3.071102    6.474013    3.8476045   1.4360788
#   5.991438    4.022748   15.576199    2.5782838   2.353082    4.4242563
#   2.3197737   0.8946167  17.294313    4.3134336   2.3267736   3.2999766
#   3.2241006   4.6365085  10.05457     7.986828    1.2275443   3.7297037
#   0.8270217   3.3390234   7.8510857   6.2161565   2.2167778   4.5843196
#   4.723469    0.6484118   1.0421376   2.090899   13.990413    1.4103189
#  11.732934    4.333482    2.9449012   6.549331   13.334653   11.625516
#   8.319152   32.773273    4.637093    1.0993439   2.9759698   1.044451
#   0.84312904  4.928733    9.123147    9.50323     7.6053286   2.149392
#   7.370951    0.24790967 34.190506   10.621396    5.3952875  21.764061
#   9.968826   10.244793    7.882654    3.3630664  20.561369    0.9117695
#  10.38185     9.761464   15.990186    3.1614356  17.025517    0.65053463
#  25.39354     7.84458     4.068838    4.659869    0.8540553  20.86761
# ...

# %% [markdown]
# # Attrition prediction

# %%
Yattr=df_train.iloc[:,[42]].values

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from matplotlib import pyplot
from imblearn.over_sampling import SMOTE

#sm = SMOTE(random_state = 2)
#X_train_res, y_train_res = sm.fit_sample(smot,Yattr)
over = SMOTE(random_state=2)
under = RandomUnderSampler(random_state=2)
steps = [('o', over), ('u', under)]
pipeline = Pipeline(steps=steps)
# transform the dataset
X_train_res, y_train_res = pipeline.fit_resample(smot, Yattr)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
X_train_res[0] == np.asarray(smot)[0]
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False,  True, False, False, False, False,  True, False,  True,
#        False, False, False, False,  True, False, False, False,  True,
#        False, False,  True,  True, False, False, False, False])

# %%
Xa_train,Xa_test,Ya_train,Ya_test = train_test_split(np.asarray(X_train_res),np.asarray(y_train_res),test_size=0.25,random_state=3)

# %%
import xgboost as xgb
model1=xgb.XGBClassifier(random_state=1,learning_rate=0.1)
#model1.fit(Xa_train, Ya_train)
#model1.score(Xa_test,Ya_test)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbclass= GradientBoostingClassifier(learning_rate=0.05,random_state=2)
#gbclass.fit(Xa_train, Ya_train)
#gbclass.score(Xa_test,Ya_test)

# %%
gbclass.fit(X_train_res, y_train_res)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.05, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=2, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
#xtest1 = np.array(xtest)

# %%
attr = gbclass.predict_proba(xtest)
attr1 = attr[:,1]
print(attr1)
# Out:
# [0.44630148 0.60700441 0.26245501 0.62846636 0.27450528 0.83232066
#  0.4296459  0.2084414  0.37837618 0.25827041 0.57007244 0.70205458
#  0.60036987 0.6068971  0.2053234  0.32443548 0.21244435 0.39533767
#  0.43400022 0.4103956  0.3552403  0.60264227 0.76170422 0.61786761
#  0.54461142 0.37421039 0.47974006 0.48947561 0.2954776  0.12437183
#  0.76150975 0.3596354  0.76906755 0.67448455 0.46596935 0.52410798
#  0.54105452 0.12620349 0.63419968 0.16288217 0.29199637 0.26913093
#  0.62542119 0.19025551 0.13928849 0.35072973 0.43279295 0.21672349
#  0.39222412 0.3813506  0.55305281 0.62913284 0.32149291 0.65368363
#  0.12597667 0.46508516 0.54763358 0.31635042 0.67415494 0.23933758
#  0.18654002 0.09134042 0.51716334 0.17802493 0.20308077 0.54971193
#  0.45863958 0.34392377 0.49771945 0.50845987 0.30308409 0.62590289
#  0.27116056 0.79198027 0.25251554 0.44426214 0.47399558 0.23638519
#  0.5136415  0.86911363 0.44441147 0.71855064 0.53594739 0.38723516
# ...

# %%
attr1.shape
# Out:
# (240,)

# %%
id = df_test['ID'].values
id.shape
# Out:
# (240,)

# %%
resultpd = np.concatenate((id.reshape(len(id),1),attr1.reshape(len(attr1),1),a.reshape(len(a),1)),1)

# %%
pd1 = pd.DataFrame(resultpd, columns = ['ID','Attrition','YearsAtCompany'])
pd1.to_csv('Submission.csv')
